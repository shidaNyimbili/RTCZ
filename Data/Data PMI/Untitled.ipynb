# %%
import os
import pandas as pd
import axis
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1f0f81359f7a> in <module>
#       1 import os
#       2 import pandas as pd
# ----> 3 import axis
#
# ModuleNotFoundError: No module named 'axis'

# %%
import os
import pandas as pd

# %%
r'C:\Users\NyimbiliShida\Documents\MSI\GIS & Visuals\R Data\Data PMI\Nchelenge Confirmed Cases Monthly 2014-20211.xlsx'
# Out:
# 'C:\\Users\\NyimbiliShida\\Documents\\MSI\\GIS & Visuals\\R Data\\Data PMI\\Nchelenge Confirmed Cases Monthly 2014-20211.xlsx'

# %%
path = r'C:\Users\NyimbiliShida\Documents\MSI\GIS & Visuals\R Data\Data PMI'
files = os.listdir(path)
print(files)
# Out:
# ['.ipynb_checkpoints', 'area plot sample.R', 'ArtusunateS.xls', 'ArtusunateSevere.xls', 'ArtusunateSs.xls', 'Book1.xls', 'Book2.xls', 'Book2.xlsx', 'Cases Monthly 2014-2021.xls', 'Copy of Nch_rainfall_2013-2020.xls', 'Copy of PMI-Vectorlink-Nchelenge IRS Data 2014 - 2021.xlsx', 'deaths.xls', 'deaths5.xls', 'dfdemo.xls', 'dfdemo.xlsx', 'dhis2.xlsx', 'districtdeathsluapula.csv', 'districtdeathsluapula.xls', 'Downlaod Extract Maternal Yearly By Province.xls', 'dydemo.xls', 'dydemo1.xls', 'HLB.R', 'hlb.xls', 'HLB_all_ns.R', 'HLB_worked.R', 'inddensity.xls', 'insecticide.xls', 'insecticideall.xls', 'insecticideinc.xls', 'insecticidetype.xls', 'ipt.xls', 'iptpreg.xls', 'irs.xls', 'malariacasesfives.xls', 'Malariaincidence.xls', 'Malaria_data.xls', 'malrain.xls', 'Manchene indoors.xls', 'Manchene outdoors.xls', 'Nchelenge Confirmed Cases Monthly 2014-2021.xls', 'Nchelenge Confirmed Cases Monthly 2014-20211.xlsx', 'Nchelenge Confirmed Cases monthly 2022.xls', 'Nchelenge Confirmed Cases.xls',
# ...

# %%
df = pd.DataFrame()

# %%
files = [f for f in files if f[-5:] == ".xlsx"]

# %%
for f in files:
    info = pd.read_excel(f, usecols=None )
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    df = df.append(info)

# %%
print(df)
# Out:
#          Year  An.funestus s.l   An.gambiae s.l   Unnamed: 0 Unnamed: 1  \
# 0  2019-06-01           78.6250           1.0625         NaN        NaN
# 1  2019-08-01           84.8125           0.3750         NaN        NaN
# 2  2019-10-01           61.3125           3.5625         NaN        NaN
# 3  2019-11-01           73.0625           2.0000         NaN        NaN
# 4  2019-12-01           45.0000           1.6875         NaN        NaN
# 5  2020-01-01           51.0625           3.3125         NaN        NaN
# 6  2020-02-01           38.0625           4.5625         NaN        NaN
# 7  2020-08-01          111.2000           1.6000         NaN        NaN
# 8  2020-09-01          130.4000           0.3000         NaN        NaN
# 9  2020-10-01           41.3000           0.1000         NaN        NaN
# 10 2020-11-01           80.8000           1.7000         NaN        NaN
# 11 2020-12-01           50.8000           0.8000         NaN        NaN
# ...

# %%
df.to_excel('Demo.xlsx', index=False)

# %%
df = pd.read_excel (r'C:\Users\NyimbiliShida\Documents\MSI\GIS & Visuals\R Data\Data PMI\Nchelenge Confirmed Cases Monthly 2014-20211.xlsx')

# %%
print (df)
# Out:
#        period  Malaria_Cases  Rainfall
# 0  2014-01-01          10782      43.7
# 1  2014-02-01          12680       6.3
# 2  2014-03-01           6527       9.4
# 3  2014-04-01          11209       0.5
# 4  2014-05-01           8168       0.0
# 5  2014-06-01           5723       0.0
# 6  2014-07-01           5266       0.0
# 7  2014-08-01           8337       0.0
# 8  2014-09-01           8440       0.9
# 9  2014-10-01           7404      16.7
# 10 2014-11-01           6203      27.2
# 11 2014-12-01           6488       8.1
# 12 2015-01-01          10901      36.4
# 13 2015-02-01           9051       5.4
# 14 2015-03-01           5255       1.2
# 15 2015-04-01           6328       1.6
# 16 2015-05-01           6818       0.0
# 17 2015-06-01           7809       0.0
# 18 2015-07-01           7940       0.0
# 19 2015-08-01           4639       0.0
# 20 2015-09-01           8476       3.5
# 21 2015-10-01           7179      20.6
# 22 2015-11-01           7884      35.3
# ...

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel (r'C:\Users\NyimbiliShida\Documents\MSI\GIS & Visuals\R Data\Data PMI\Nchelenge Confirmed Cases Monthly 2014-20211.xlsx')

# %%
plt.plot(df)
